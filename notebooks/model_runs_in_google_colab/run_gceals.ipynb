# %%
import torch.nn as nn


class Autoencoder(nn.Module):
    def __init__(self, input_dim, latent_dim):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 500),
            nn.ReLU(),
            nn.Linear(500, 500),
            nn.ReLU(),
            nn.Linear(500, 2000),
            nn.ReLU(),
            nn.Linear(2000, latent_dim)
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 2000),
            nn.ReLU(),
            nn.Linear(2000, 500),
            nn.ReLU(),
            nn.Linear(500, 500),
            nn.ReLU(),
            nn.Linear(500, input_dim)
        )

    def forward(self, x):
        z = self.encoder(x)
        x_hat = self.decoder(z)
        return z, x_hat

# %%
import torch.nn as nn
import torch
import torch.nn.functional as F
from sklearn.cluster import KMeans


class GCEALsHead(nn.Module):
    def __init__(self, latent_dim, n_clusters):
        super().__init__()
        self.n_clusters = n_clusters

        # Centroids μ_j (to be initialized with k-means, Algorithm 1 step 6)
        self.centroids = nn.Parameter(torch.zeros(n_clusters, latent_dim))

        # Diagonal covariance Σ_j = diag(exp(logvar))
        self.logvar = nn.Parameter(torch.zeros(n_clusters, latent_dim))

        # MLP Head for auxiliary distribution Q (Eq. 10)
        self.mlp = nn.Linear(latent_dim, n_clusters)

    def forward(self, z):
        """
        Returns:
          P = cluster distribution from Gaussian/Mahalanobis (Eq. 6–9)
          Q = cluster distribution from MLP head (Eq. 10)
        """
        if z.dim() == 1:  # single sample (D,)
            z = z.unsqueeze(0)  # → (1, D)

        B, D = z.shape

        # --- Gaussian assignment (P) ---
        # Expand z to (B, K, D)
        z_exp = z.unsqueeze(1).expand(B, self.n_clusters, D)  # (B, K, D)
        mu = self.centroids.unsqueeze(0).expand(B, self.n_clusters, D)  # (B, K, D)
        var = torch.exp(self.logvar).unsqueeze(0).expand(B, self.n_clusters, D)  # (B, K, D)

        dist = torch.sqrt(((z_exp - mu) ** 2 / var).sum(dim=2))  # (B, K)
        P = F.softmax(-dist, dim=1)  # soft assignments across clusters

        # --- MLP assignment (Q) ---
        logits = self.mlp(z)  # (B, K)
        Q = F.softmax(logits, dim=1)

        return P, Q


class GCEALs(nn.Module):
    def __init__(self, input_dim, latent_dim, n_clusters):
        super().__init__()
        self.ae = Autoencoder(input_dim, latent_dim)
        self.cluster_head = GCEALsHead(latent_dim, n_clusters)
        self.n_clusters = n_clusters
        self.pi = None  # cluster priors (Eq. 8)

    def forward(self, x):
        z, x_hat = self.ae(x)
        P, Q = self.cluster_head(z)
        return P, Q, x_hat, z

    def pretrain(self, dataloader, optimizer, epochs=50, device='cuda', patience=10):
        """
        Pretrain autoencoder only (Eq. 11).
        """
        self.train()
        self.to(device)
        loss_fn = nn.MSELoss()

        best_loss = float('inf')
        patience_counter = 0

        for epoch in range(epochs):
            total_loss, n_samples = 0.0, 0

            for x_batch in dataloader:
                x_batch = x_batch.to(device)
                _, x_hat = self.ae(x_batch)
                loss = loss_fn(x_hat, x_batch)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                total_loss += loss.item() * x_batch.size(0)
                n_samples += x_batch.size(0)

            avg_loss = total_loss / n_samples
            print(f'[Pretrain] Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}')

            # --- Early stopping check ---
            if avg_loss < best_loss - 1e-4:  # small tolerance
                best_loss = avg_loss
                patience_counter = 0
            else:
                patience_counter += 1

            if patience_counter >= patience:
                print(f'[Pretrain] Early stopping at epoch {epoch+1}, best loss={best_loss:.4f}')
                break

    def init_centroids(self, dataloader, device='cuda'):
        """
        Initialize centroids μ_j using k-means on latent space (Alg. 1, step 6).
        """
        self.eval()
        all_z = []
        with torch.no_grad():
            for x_batch in dataloader:
                x_batch = x_batch.to(device)
                z, _ = self.ae(x_batch)
                all_z.append(z.cpu())
        all_z = torch.cat(all_z, dim=0).numpy()

        # Run k-means
        kmeans = KMeans(n_clusters=self.n_clusters, n_init=20)
        kmeans.fit(all_z)
        centroids = torch.tensor(kmeans.cluster_centers_, dtype=torch.float)

        # Initialize cluster centroids μ_j
        self.cluster_head.centroids.data.copy_(centroids)

        # Initialize priors ω_j equally (Eq. 8)
        self.pi = torch.ones(self.n_clusters, device=device) / self.n_clusters
        print("[Init] Centroids initialized with k-means")

    def train_gceals(self, dataloader, optimizer, epochs=100, device='cuda', gamma=1.0):
        """
        Joint training of AE + clustering (Algorithm 1).
        Loss = L_rec + γ * KL(P || Q)   (Eq. 13)
        """
        self.train()
        self.to(device)
        recon_loss_fn = nn.MSELoss()

        for epoch in range(epochs):
            total_loss, n_samples = 0.0, 0

            for x_batch in dataloader:
                x_batch = x_batch.to(device)

                # Forward pass
                P, Q, x_hat, z = self(x_batch)  # P=Gaussian, Q=MLP

                # ====== Loss ======
                recon_loss = recon_loss_fn(x_hat, x_batch)
                kl_div = F.kl_div(Q.log(), P, reduction='batchmean')  # KL(P || Q)
                loss = recon_loss + gamma * kl_div

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                total_loss += loss.item() * x_batch.size(0)
                n_samples += x_batch.size(0)

            # ====== Update priors ω_j (Eq. 8) ======
            with torch.no_grad():
                all_P = []
                for x_batch in dataloader:
                    x_batch = x_batch.to(device)
                    P, _, _, _ = self(x_batch)
                    all_P.append(P)
                all_P = torch.stack(all_P, dim=0)
                self.pi = all_P.mean(dim=0)

            avg_loss = total_loss / n_samples
            print(f'[GCEALs] Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}')

            # ====== Early stopping check (Algorithm 1) ======
            if torch.any(self.pi <= 1.0 / (2 * self.n_clusters)):
                print(f"[Early Stopping] Cluster prior too small: {self.pi}")
                break

# %%
import torch
import torch.optim as optim
import pandas as pd
import numpy as np
import os
import sys
from torch.utils.data import DataLoader, TensorDataset
import json
from pathlib import Path

from sklearn.metrics import confusion_matrix, accuracy_score, adjusted_rand_score
from scipy.optimize import linear_sum_assignment


# Config
DATA_PATH = 'data_processed.csv'
LABEL_PATH = 'clusters.csv'
METADATA_PATH = 'metadata.json'


dataset_index = '37'



with open(METADATA_PATH, 'r') as f:
  metadata = json.load(f)
num_numeric = metadata['num_numerical_features']
categories = metadata['num_classes_per_cat']
n_clusters = metadata['num_clusters']


pretrain_epochs = 100
train_epochs = 20
batch_size = 256
lr = 1e-3
gamma=0.1



device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load data
x_real = pd.read_csv(DATA_PATH).values.astype(np.float32)
y_true = pd.read_csv(LABEL_PATH).values.flatten()
if y_true.dtype.kind in {'U', 'S', 'O'}:
    unique_labels, y_true = np.unique(np.asarray(y_true).astype(str), return_inverse=True)
x_real = torch.tensor(x_real, dtype=torch.float32).to(device)
dataset = TensorDataset(x_real)
dataloader = DataLoader(dataset, batch_size=128, shuffle=True)
N, D = x_real.shape



BEST_PATH = f"best_checkpoint_{dataset_index}.pth"
best_acc = -1.0
best_meta = None
for latent_dim in [5, 10, 15, 20]:
  print(f"latent_dim: {latent_dim}")
  # Models
  model = GCEALs(input_dim=D, latent_dim=latent_dim, n_clusters=n_clusters).to(device)


  # Optimizer
  optimizer = optim.Adam(model.parameters(), lr=lr)

  # Pretrain AE
  print("🔹 Pretraining autoencoder...")
  model.pretrain(x_real, optimizer, epochs=pretrain_epochs, device=device)

  # Full training
  print("🔹 Training GCEALs model...")
  model.train_gceals(x_real, optimizer, epochs=train_epochs, device=device, gamma=gamma)

  # Predict cluster assignments
  model.eval()
  with torch.no_grad():
      z, _ = model.ae(x_real)
      _, q = model.cluster_head(z)
      y_pred = q.argmax(dim=1).cpu().numpy()

  # Alignment
  def cluster_accuracy(y_true, y_pred):
      contingency = confusion_matrix(y_true, y_pred)
      row_ind, col_ind = linear_sum_assignment(-contingency)
      mapping = dict(zip(col_ind, row_ind))
      y_aligned = np.array([mapping[label] for label in y_pred])
      acc = accuracy_score(y_true, y_aligned)
      return acc, y_aligned

  accuracy, y_aligned = cluster_accuracy(y_true, y_pred)
  ari = adjusted_rand_score(y_true, y_pred)

  print(f"✅ Final clustering performance:")
  print(f"Accuracy: {accuracy:.4f}")
  print(f"ARI: {ari:.4f}")


  # Example: after you finish one training run
  results = {
      "accuracy": float(accuracy),      # your computed accuracy
      "ari": float(ari),                # your computed ARI
      "latent_dim": int(latent_dim),    # latent dimension
      "dataset_index": str(dataset_index)      # e.g., "mnist", "cifar10", etc.
  }

  # Path to results file
  results_file = Path("gceals_results.json")

  # If file exists, load and append; else create new
  if results_file.exists():
      with open(results_file, "r") as f:
          all_results = json.load(f)
  else:
      all_results = []

  all_results.append(results)

  # Save updated results
  with open(results_file, "w") as f:
      json.dump(all_results, f, indent=4)

  print(f"Saved results to {results_file}\n")

  # --- NEW: update 'best' and save checkpoint if improved ---
  if accuracy > best_acc:
      best_acc = float(accuracy)
      best_meta = {
          "latent_dim": int(latent_dim),
          "dataset_index": str(dataset_index),
          "accuracy": float(accuracy),
          "ari": float(ari)
      }

      torch.save({
          "model_state": model.state_dict(),                # AE + cluster head
            "optimizer_state": optimizer.state_dict() if optimizer is not None else None,
            "config": {
                "input_dim": D,
                "latent_dim": latent_dim,
                "n_clusters": n_clusters,
                "lr": lr,
                "batch_size": batch_size,
                "pretrain_epochs": pretrain_epochs,
                "gceals_epochs": train_epochs,
                "gamma": gamma,
                "architecture": {
                    "encoder_layers": [D, 500, 500, 2000, latent_dim],
                    "decoder_layers": [latent_dim, 2000, 500, 500, D],
                    },
                },
            "metrics": {
                "accuracy": float(accuracy),
                "ari": float(ari)
                }
            }, BEST_PATH)

      print(f"💾 New best model saved to {BEST_PATH} (acc={accuracy:.4f}, z={latent_dim}, K={n_clusters})")
    # ----------------------------------------------------------

# --- after both loops finish ---
print("🏁 Tuning finished.")
print(f"Best acc: {best_acc:.4f}")
if best_meta is not None:
    print(f"Best config: latent_dim={best_meta['latent_dim']}")
# Out:
# latent_dim: 5
# 🔹 Pretraining autoencoder...
# [Pretrain] Epoch 1/100, Loss: 2.1478
# [Pretrain] Epoch 2/100, Loss: 1.5777
# [Pretrain] Epoch 3/100, Loss: 1.2285
# [Pretrain] Epoch 4/100, Loss: 0.9982
# [Pretrain] Epoch 5/100, Loss: 0.9848
# [Pretrain] Epoch 6/100, Loss: 0.9445
# [Pretrain] Epoch 7/100, Loss: 0.8180
# [Pretrain] Epoch 8/100, Loss: 0.7329
# [Pretrain] Epoch 9/100, Loss: 0.6794
# [Pretrain] Epoch 10/100, Loss: 0.6460
# [Pretrain] Epoch 11/100, Loss: 0.7188
# [Pretrain] Epoch 12/100, Loss: 0.5657
# [Pretrain] Epoch 13/100, Loss: 0.5549
# [Pretrain] Epoch 14/100, Loss: 0.5368
# [Pretrain] Epoch 15/100, Loss: 0.6294
# [Pretrain] Epoch 16/100, Loss: 0.4759
# [Pretrain] Epoch 17/100, Loss: 0.5130
# [Pretrain] Epoch 18/100, Loss: 0.4619
# [Pretrain] Epoch 19/100, Loss: 0.4508
# [Pretrain] Epoch 20/100, Loss: 0.4992
# [Pretrain] Epoch 21/100, Loss: 0.3922
# [Pretrain] Epoch 22/100, Loss: 0.4297
# [Pretrain] Epoch 23/100, Loss: 0.4057
# [Pretrain] Epoch 24/100, Loss: 0.4032
# [Pretrain] Epoch 25/100, Loss: 0.3723
# [Pretrain] Epoch 26/100, Loss: 0.4084
# [Pretrain] Epoch 27/100, Loss: 0.3709
# [Pretrain] Epoch 28/100, Loss: 0.3738
# [Pretrain] Epoch 29/100, Loss: 0.3758
# [Pretrain] Epoch 30/100, Loss: 0.4059
# [Pretrain] Epoch 31/100, Loss: 0.3350
# [Pretrain] Epoch 32/100, Loss: 0.3438
# [Pretrain] Epoch 33/100, Loss: 0.3192
# [Pretrain] Epoch 34/100, Loss: 0.3042
# [Pretrain] Epoch 35/100, Loss: 0.3469
# [Pretrain] Epoch 36/100, Loss: 0.3229
# [Pretrain] Epoch 37/100, Loss: 0.2909
# [Pretrain] Epoch 38/100, Loss: 0.3144
# [Pretrain] Epoch 39/100, Loss: 0.3000
# [Pretrain] Epoch 40/100, Loss: 0.3010
# [Pretrain] Epoch 41/100, Loss: 0.3213
# [Pretrain] Epoch 42/100, Loss: 0.2799
# [Pretrain] Epoch 43/100, Loss: 0.2424
# [Pretrain] Epoch 44/100, Loss: 0.2964
# [Pretrain] Epoch 45/100, Loss: 0.2931
# [Pretrain] Epoch 46/100, Loss: 0.2657
# [Pretrain] Epoch 47/100, Loss: 0.3007
# [Pretrain] Epoch 48/100, Loss: 0.2509
# [Pretrain] Epoch 49/100, Loss: 0.2678
# [Pretrain] Epoch 50/100, Loss: 0.2150
# [Pretrain] Epoch 51/100, Loss: 0.2619
# [Pretrain] Epoch 52/100, Loss: 0.2209
# [Pretrain] Epoch 53/100, Loss: 0.2512
# [Pretrain] Epoch 54/100, Loss: 0.2811
# [Pretrain] Epoch 55/100, Loss: 0.2485
# [Pretrain] Epoch 56/100, Loss: 0.2269
# [Pretrain] Epoch 57/100, Loss: 0.1830
# [Pretrain] Epoch 58/100, Loss: 0.1948
# [Pretrain] Epoch 59/100, Loss: 0.2190
# [Pretrain] Epoch 60/100, Loss: 0.2185
# [Pretrain] Epoch 61/100, Loss: 0.2038
# [Pretrain] Epoch 62/100, Loss: 0.1871
# [Pretrain] Epoch 63/100, Loss: 0.1777
# [Pretrain] Epoch 64/100, Loss: 0.1886
# [Pretrain] Epoch 65/100, Loss: 0.2426
# [Pretrain] Epoch 66/100, Loss: 0.2235
# [Pretrain] Epoch 67/100, Loss: 0.1853
# [Pretrain] Epoch 68/100, Loss: 0.2014
# [Pretrain] Epoch 69/100, Loss: 0.1752
# [Pretrain] Epoch 70/100, Loss: 0.1619
# [Pretrain] Epoch 71/100, Loss: 0.1974
# [Pretrain] Epoch 72/100, Loss: 0.1922
# [Pretrain] Epoch 73/100, Loss: 0.1536
# [Pretrain] Epoch 74/100, Loss: 0.2013
# [Pretrain] Epoch 75/100, Loss: 0.2092
# [Pretrain] Epoch 76/100, Loss: 0.1507
# [Pretrain] Epoch 77/100, Loss: 0.1566
# [Pretrain] Epoch 78/100, Loss: 0.1790
# [Pretrain] Epoch 79/100, Loss: 0.1534
# [Pretrain] Epoch 80/100, Loss: 0.1484
# [Pretrain] Epoch 81/100, Loss: 0.2367
# [Pretrain] Epoch 82/100, Loss: 0.1620
# [Pretrain] Epoch 83/100, Loss: 0.1377
# [Pretrain] Epoch 84/100, Loss: 0.1618
# [Pretrain] Epoch 85/100, Loss: 0.1717
# [Pretrain] Epoch 86/100, Loss: 0.1773
# [Pretrain] Epoch 87/100, Loss: 0.1716
# [Pretrain] Epoch 88/100, Loss: 0.1888
# [Pretrain] Epoch 89/100, Loss: 0.1569
# [Pretrain] Epoch 90/100, Loss: 0.1359
# [Pretrain] Epoch 91/100, Loss: 0.1425
# [Pretrain] Epoch 92/100, Loss: 0.1372
# [Pretrain] Epoch 93/100, Loss: 0.1724
# [Pretrain] Epoch 94/100, Loss: 0.1796
# [Pretrain] Epoch 95/100, Loss: 0.1660
# [Pretrain] Epoch 96/100, Loss: 0.1351
# [Pretrain] Epoch 97/100, Loss: 0.1230
# [Pretrain] Epoch 98/100, Loss: 0.1345
# [Pretrain] Epoch 99/100, Loss: 0.1240
# [Pretrain] Epoch 100/100, Loss: 0.1478
# 🔹 Training GCEALs model...
# [GCEALs] Epoch 1/20, Loss: 0.1535
# [GCEALs] Epoch 2/20, Loss: 0.1489
# [GCEALs] Epoch 3/20, Loss: 0.1646
# [GCEALs] Epoch 4/20, Loss: 0.1234
# [GCEALs] Epoch 5/20, Loss: 0.1125
# [GCEALs] Epoch 6/20, Loss: 0.1264
# [GCEALs] Epoch 7/20, Loss: 0.1161
# [GCEALs] Epoch 8/20, Loss: 0.1158
# [GCEALs] Epoch 9/20, Loss: 0.1820
# [GCEALs] Epoch 10/20, Loss: 0.1355
# [GCEALs] Epoch 11/20, Loss: 0.1181
# [GCEALs] Epoch 12/20, Loss: 0.1136
# [GCEALs] Epoch 13/20, Loss: 0.1397
# [GCEALs] Epoch 14/20, Loss: 0.1300
# [GCEALs] Epoch 15/20, Loss: 0.1572
# [GCEALs] Epoch 16/20, Loss: 0.1206
# [GCEALs] Epoch 17/20, Loss: 0.1139
# [GCEALs] Epoch 18/20, Loss: 0.1125
# [GCEALs] Epoch 19/20, Loss: 0.1106
# [GCEALs] Epoch 20/20, Loss: 0.1181
# ✅ Final clustering performance:
# Accuracy: 0.6510
# ARI: 0.0000
# Saved results to gceals_results.json
#
# 💾 New best model saved to best_checkpoint_37.pth (acc=0.6510, z=5, K=2)
# latent_dim: 10
# 🔹 Pretraining autoencoder...
# [Pretrain] Epoch 1/100, Loss: 2.0807
# [Pretrain] Epoch 2/100, Loss: 1.7006
# [Pretrain] Epoch 3/100, Loss: 1.2954
# [Pretrain] Epoch 4/100, Loss: 1.2140
# [Pretrain] Epoch 5/100, Loss: 1.0172
# [Pretrain] Epoch 6/100, Loss: 0.8773
# [Pretrain] Epoch 7/100, Loss: 0.6855
# [Pretrain] Epoch 8/100, Loss: 0.7188
# [Pretrain] Epoch 9/100, Loss: 0.6314
# [Pretrain] Epoch 10/100, Loss: 0.6571
# [Pretrain] Epoch 11/100, Loss: 0.5839
# [Pretrain] Epoch 12/100, Loss: 0.5706
# [Pretrain] Epoch 13/100, Loss: 0.5565
# [Pretrain] Epoch 14/100, Loss: 0.5339
# [Pretrain] Epoch 15/100, Loss: 0.4508
# [Pretrain] Epoch 16/100, Loss: 0.4670
# [Pretrain] Epoch 17/100, Loss: 0.4490
# [Pretrain] Epoch 18/100, Loss: 0.3919
# [Pretrain] Epoch 19/100, Loss: 0.3718
# [Pretrain] Epoch 20/100, Loss: 0.3587
# [Pretrain] Epoch 21/100, Loss: 0.3462
# [Pretrain] Epoch 22/100, Loss: 0.3103
# [Pretrain] Epoch 23/100, Loss: 0.3336
# [Pretrain] Epoch 24/100, Loss: 0.3002
# [Pretrain] Epoch 25/100, Loss: 0.3483
# [Pretrain] Epoch 26/100, Loss: 0.2676
# [Pretrain] Epoch 27/100, Loss: 0.2963
# [Pretrain] Epoch 28/100, Loss: 0.2662
# [Pretrain] Epoch 29/100, Loss: 0.2577
# [Pretrain] Epoch 30/100, Loss: 0.2415
# [Pretrain] Epoch 31/100, Loss: 0.2537
# [Pretrain] Epoch 32/100, Loss: 0.2377
# [Pretrain] Epoch 33/100, Loss: 0.2070
# [Pretrain] Epoch 34/100, Loss: 0.2317
# [Pretrain] Epoch 35/100, Loss: 0.2399
# [Pretrain] Epoch 36/100, Loss: 0.2168
# [Pretrain] Epoch 37/100, Loss: 0.2300
# [Pretrain] Epoch 38/100, Loss: 0.2047
# [Pretrain] Epoch 39/100, Loss: 0.2111
# [Pretrain] Epoch 40/100, Loss: 0.2106
# [Pretrain] Epoch 41/100, Loss: 0.2142
# [Pretrain] Epoch 42/100, Loss: 0.1814
# [Pretrain] Epoch 43/100, Loss: 0.1977
# [Pretrain] Epoch 44/100, Loss: 0.1983
# [Pretrain] Epoch 45/100, Loss: 0.1730
# [Pretrain] Epoch 46/100, Loss: 0.1811
# [Pretrain] Epoch 47/100, Loss: 0.1831
# [Pretrain] Epoch 48/100, Loss: 0.2086
# [Pretrain] Epoch 49/100, Loss: 0.1685
# [Pretrain] Epoch 50/100, Loss: 0.1722
# [Pretrain] Epoch 51/100, Loss: 0.1811
# [Pretrain] Epoch 52/100, Loss: 0.1904
# [Pretrain] Epoch 53/100, Loss: 0.1536
# [Pretrain] Epoch 54/100, Loss: 0.1941
# [Pretrain] Epoch 55/100, Loss: 0.1690
# [Pretrain] Epoch 56/100, Loss: 0.1708
# [Pretrain] Epoch 57/100, Loss: 0.1563
# [Pretrain] Epoch 58/100, Loss: 0.1365
# [Pretrain] Epoch 59/100, Loss: 0.1547
# [Pretrain] Epoch 60/100, Loss: 0.1893
# [Pretrain] Epoch 61/100, Loss: 0.1616
# [Pretrain] Epoch 62/100, Loss: 0.1316
# [Pretrain] Epoch 63/100, Loss: 0.1723
# [Pretrain] Epoch 64/100, Loss: 0.1667
# [Pretrain] Epoch 65/100, Loss: 0.1366
# [Pretrain] Epoch 66/100, Loss: 0.1243
# [Pretrain] Epoch 67/100, Loss: 0.1507
# [Pretrain] Epoch 68/100, Loss: 0.1452
# [Pretrain] Epoch 69/100, Loss: 0.1439
# [Pretrain] Epoch 70/100, Loss: 0.1560
# [Pretrain] Epoch 71/100, Loss: 0.1384
# [Pretrain] Epoch 72/100, Loss: 0.1642
# [Pretrain] Epoch 73/100, Loss: 0.1327
# [Pretrain] Epoch 74/100, Loss: 0.1333
# [Pretrain] Epoch 75/100, Loss: 0.1546
# [Pretrain] Epoch 76/100, Loss: 0.1401
# [Pretrain] Early stopping at epoch 76, best loss=0.1243
# 🔹 Training GCEALs model...
# [GCEALs] Epoch 1/20, Loss: 0.1368
# [GCEALs] Epoch 2/20, Loss: 0.1342
# [GCEALs] Epoch 3/20, Loss: 0.1710
# [GCEALs] Epoch 4/20, Loss: 0.1506
# [GCEALs] Epoch 5/20, Loss: 0.1237
# [GCEALs] Epoch 6/20, Loss: 0.1334
# [GCEALs] Epoch 7/20, Loss: 0.1219
# [GCEALs] Epoch 8/20, Loss: 0.1254
# [GCEALs] Epoch 9/20, Loss: 0.1459
# [GCEALs] Epoch 10/20, Loss: 0.1609
# [GCEALs] Epoch 11/20, Loss: 0.1675
# [GCEALs] Epoch 12/20, Loss: 0.1294
# [GCEALs] Epoch 13/20, Loss: 0.1137
# [GCEALs] Epoch 14/20, Loss: 0.1169
# [GCEALs] Epoch 15/20, Loss: 0.1758
# [GCEALs] Epoch 16/20, Loss: 0.1396
# [GCEALs] Epoch 17/20, Loss: 0.1329
# [GCEALs] Epoch 18/20, Loss: 0.1231
# [GCEALs] Epoch 19/20, Loss: 0.1320
# [GCEALs] Epoch 20/20, Loss: 0.1319
# ✅ Final clustering performance:
# Accuracy: 0.6510
# ARI: 0.0000
# Saved results to gceals_results.json
#
# latent_dim: 15
# 🔹 Pretraining autoencoder...
# [Pretrain] Epoch 1/100, Loss: 2.2250
# [Pretrain] Epoch 2/100, Loss: 1.5262
# [Pretrain] Epoch 3/100, Loss: 1.4551
# [Pretrain] Epoch 4/100, Loss: 1.1474
# [Pretrain] Epoch 5/100, Loss: 0.9202
# [Pretrain] Epoch 6/100, Loss: 0.8926
# [Pretrain] Epoch 7/100, Loss: 0.8319
# [Pretrain] Epoch 8/100, Loss: 0.9039
# [Pretrain] Epoch 9/100, Loss: 0.6581
# [Pretrain] Epoch 10/100, Loss: 0.6182
# [Pretrain] Epoch 11/100, Loss: 0.5824
# [Pretrain] Epoch 12/100, Loss: 0.7159
# [Pretrain] Epoch 13/100, Loss: 0.6452
# [Pretrain] Epoch 14/100, Loss: 0.5692
# [Pretrain] Epoch 15/100, Loss: 0.5923
# [Pretrain] Epoch 16/100, Loss: 0.4642
# [Pretrain] Epoch 17/100, Loss: 0.4858
# [Pretrain] Epoch 18/100, Loss: 0.5043
# [Pretrain] Epoch 19/100, Loss: 0.4225
# [Pretrain] Epoch 20/100, Loss: 0.4722
# [Pretrain] Epoch 21/100, Loss: 0.4070
# [Pretrain] Epoch 22/100, Loss: 0.4402
# [Pretrain] Epoch 23/100, Loss: 0.3810
# [Pretrain] Epoch 24/100, Loss: 0.3790
# [Pretrain] Epoch 25/100, Loss: 0.3188
# [Pretrain] Epoch 26/100, Loss: 0.3276
# [Pretrain] Epoch 27/100, Loss: 0.3053
# [Pretrain] Epoch 28/100, Loss: 0.2667
# [Pretrain] Epoch 29/100, Loss: 0.2892
# [Pretrain] Epoch 30/100, Loss: 0.2955
# [Pretrain] Epoch 31/100, Loss: 0.3026
# [Pretrain] Epoch 32/100, Loss: 0.3203
# [Pretrain] Epoch 33/100, Loss: 0.2927
# [Pretrain] Epoch 34/100, Loss: 0.2733
# [Pretrain] Epoch 35/100, Loss: 0.2297
# [Pretrain] Epoch 36/100, Loss: 0.2436
# [Pretrain] Epoch 37/100, Loss: 0.2315
# [Pretrain] Epoch 38/100, Loss: 0.2688
# [Pretrain] Epoch 39/100, Loss: 0.2468
# [Pretrain] Epoch 40/100, Loss: 0.1960
# [Pretrain] Epoch 41/100, Loss: 0.2800
# [Pretrain] Epoch 42/100, Loss: 0.2526
# [Pretrain] Epoch 43/100, Loss: 0.1919
# [Pretrain] Epoch 44/100, Loss: 0.2044
# [Pretrain] Epoch 45/100, Loss: 0.2104
# [Pretrain] Epoch 46/100, Loss: 0.2545
# [Pretrain] Epoch 47/100, Loss: 0.2535
# [Pretrain] Epoch 48/100, Loss: 0.2577
# [Pretrain] Epoch 49/100, Loss: 0.2071
# [Pretrain] Epoch 50/100, Loss: 0.2700
# [Pretrain] Epoch 51/100, Loss: 0.2359
# [Pretrain] Epoch 52/100, Loss: 0.1951
# [Pretrain] Epoch 53/100, Loss: 0.2028
# [Pretrain] Early stopping at epoch 53, best loss=0.1919
# 🔹 Training GCEALs model...
# [GCEALs] Epoch 1/20, Loss: 0.1969
# [GCEALs] Epoch 2/20, Loss: 0.2164
# [GCEALs] Epoch 3/20, Loss: 0.2730
# [GCEALs] Epoch 4/20, Loss: 0.1730
# [GCEALs] Epoch 5/20, Loss: 0.1693
# [GCEALs] Epoch 6/20, Loss: 0.1777
# [GCEALs] Epoch 7/20, Loss: 0.2108
# [GCEALs] Epoch 8/20, Loss: 0.2162
# [GCEALs] Epoch 9/20, Loss: 0.2089
# [GCEALs] Epoch 10/20, Loss: 0.1793
# [GCEALs] Epoch 11/20, Loss: 0.1776
# [GCEALs] Epoch 12/20, Loss: 0.1719
# [GCEALs] Epoch 13/20, Loss: 0.1848
# [GCEALs] Epoch 14/20, Loss: 0.1816
# [GCEALs] Epoch 15/20, Loss: 0.1668
# [GCEALs] Epoch 16/20, Loss: 0.2073
# [GCEALs] Epoch 17/20, Loss: 0.1963
# [GCEALs] Epoch 18/20, Loss: 0.1967
# [GCEALs] Epoch 19/20, Loss: 0.1380
# [GCEALs] Epoch 20/20, Loss: 0.1498
# ✅ Final clustering performance:
# Accuracy: 0.6510
# ARI: 0.0000
# Saved results to gceals_results.json
#
# latent_dim: 20
# 🔹 Pretraining autoencoder...
# [Pretrain] Epoch 1/100, Loss: 2.1289
# [Pretrain] Epoch 2/100, Loss: 1.5533
# [Pretrain] Epoch 3/100, Loss: 1.4317
# [Pretrain] Epoch 4/100, Loss: 1.1470
# [Pretrain] Epoch 5/100, Loss: 1.0647
# [Pretrain] Epoch 6/100, Loss: 0.9426
# [Pretrain] Epoch 7/100, Loss: 0.8198
# [Pretrain] Epoch 8/100, Loss: 0.7734
# [Pretrain] Epoch 9/100, Loss: 0.7028
# [Pretrain] Epoch 10/100, Loss: 0.6539
# [Pretrain] Epoch 11/100, Loss: 0.6495
# [Pretrain] Epoch 12/100, Loss: 0.6200
# [Pretrain] Epoch 13/100, Loss: 0.6037
# [Pretrain] Epoch 14/100, Loss: 0.5780
# [Pretrain] Epoch 15/100, Loss: 0.5548
# [Pretrain] Epoch 16/100, Loss: 0.4758
# [Pretrain] Epoch 17/100, Loss: 0.4603
# [Pretrain] Epoch 18/100, Loss: 0.4321
# [Pretrain] Epoch 19/100, Loss: 0.4718
# [Pretrain] Epoch 20/100, Loss: 0.4188
# [Pretrain] Epoch 21/100, Loss: 0.4184
# [Pretrain] Epoch 22/100, Loss: 0.3491
# [Pretrain] Epoch 23/100, Loss: 0.3448
# [Pretrain] Epoch 24/100, Loss: 0.3262
# [Pretrain] Epoch 25/100, Loss: 0.3642
# [Pretrain] Epoch 26/100, Loss: 0.2831
# [Pretrain] Epoch 27/100, Loss: 0.3034
# [Pretrain] Epoch 28/100, Loss: 0.2873
# [Pretrain] Epoch 29/100, Loss: 0.2980
# [Pretrain] Epoch 30/100, Loss: 0.2688
# [Pretrain] Epoch 31/100, Loss: 0.2783
# [Pretrain] Epoch 32/100, Loss: 0.2766
# [Pretrain] Epoch 33/100, Loss: 0.1939
# [Pretrain] Epoch 34/100, Loss: 0.2134
# [Pretrain] Epoch 35/100, Loss: 0.2619
# [Pretrain] Epoch 36/100, Loss: 0.2337
# [Pretrain] Epoch 37/100, Loss: 0.2001
# [Pretrain] Epoch 38/100, Loss: 0.1961
# [Pretrain] Epoch 39/100, Loss: 0.1965
# [Pretrain] Epoch 40/100, Loss: 0.1766
# [Pretrain] Epoch 41/100, Loss: 0.1627
# [Pretrain] Epoch 42/100, Loss: 0.2025
# [Pretrain] Epoch 43/100, Loss: 0.1886
# [Pretrain] Epoch 44/100, Loss: 0.1461
# [Pretrain] Epoch 45/100, Loss: 0.2039
# [Pretrain] Epoch 46/100, Loss: 0.1525
# [Pretrain] Epoch 47/100, Loss: 0.1193
# [Pretrain] Epoch 48/100, Loss: 0.1319
# [Pretrain] Epoch 49/100, Loss: 0.1531
# [Pretrain] Epoch 50/100, Loss: 0.1601
# [Pretrain] Epoch 51/100, Loss: 0.1863
# [Pretrain] Epoch 52/100, Loss: 0.1130
# [Pretrain] Epoch 53/100, Loss: 0.1451
# [Pretrain] Epoch 54/100, Loss: 0.1163
# [Pretrain] Epoch 55/100, Loss: 0.1442
# [Pretrain] Epoch 56/100, Loss: 0.1053
# [Pretrain] Epoch 57/100, Loss: 0.1175
# [Pretrain] Epoch 58/100, Loss: 0.1070
# [Pretrain] Epoch 59/100, Loss: 0.1162
# [Pretrain] Epoch 60/100, Loss: 0.1065
# [Pretrain] Epoch 61/100, Loss: 0.1295
# [Pretrain] Epoch 62/100, Loss: 0.1095
# [Pretrain] Epoch 63/100, Loss: 0.0947
# [Pretrain] Epoch 64/100, Loss: 0.0971
# [Pretrain] Epoch 65/100, Loss: 0.0877
# [Pretrain] Epoch 66/100, Loss: 0.1272
# [Pretrain] Epoch 67/100, Loss: 0.0889
# [Pretrain] Epoch 68/100, Loss: 0.0864
# [Pretrain] Epoch 69/100, Loss: 0.0973
# [Pretrain] Epoch 70/100, Loss: 0.0826
# [Pretrain] Epoch 71/100, Loss: 0.0902
# [Pretrain] Epoch 72/100, Loss: 0.0918
# [Pretrain] Epoch 73/100, Loss: 0.1524
# [Pretrain] Epoch 74/100, Loss: 0.1002
# [Pretrain] Epoch 75/100, Loss: 0.0738
# [Pretrain] Epoch 76/100, Loss: 0.0644
# [Pretrain] Epoch 77/100, Loss: 0.0705
# [Pretrain] Epoch 78/100, Loss: 0.0979
# [Pretrain] Epoch 79/100, Loss: 0.0977
# [Pretrain] Epoch 80/100, Loss: 0.0829
# [Pretrain] Epoch 81/100, Loss: 0.0922
# [Pretrain] Epoch 82/100, Loss: 0.0782
# [Pretrain] Epoch 83/100, Loss: 0.0945
# [Pretrain] Epoch 84/100, Loss: 0.0806
# [Pretrain] Epoch 85/100, Loss: 0.0691
# [Pretrain] Epoch 86/100, Loss: 0.0793
# [Pretrain] Early stopping at epoch 86, best loss=0.0644
# 🔹 Training GCEALs model...
# [GCEALs] Epoch 1/20, Loss: 0.0668
# [GCEALs] Epoch 2/20, Loss: 0.0714
# [GCEALs] Epoch 3/20, Loss: 0.0879
# [GCEALs] Epoch 4/20, Loss: 0.0907
# [GCEALs] Epoch 5/20, Loss: 0.0766
# [GCEALs] Epoch 6/20, Loss: 0.0561
# [GCEALs] Epoch 7/20, Loss: 0.0604
# [GCEALs] Epoch 8/20, Loss: 0.0790
# [GCEALs] Epoch 9/20, Loss: 0.0800
# [GCEALs] Epoch 10/20, Loss: 0.0673
# [GCEALs] Epoch 11/20, Loss: 0.0692
# [GCEALs] Epoch 12/20, Loss: 0.0557
# [GCEALs] Epoch 13/20, Loss: 0.0742
# [GCEALs] Epoch 14/20, Loss: 0.0701
# [GCEALs] Epoch 15/20, Loss: 0.0584
# [GCEALs] Epoch 16/20, Loss: 0.0462
# [GCEALs] Epoch 17/20, Loss: 0.0562
# [GCEALs] Epoch 18/20, Loss: 0.0609
# [GCEALs] Epoch 19/20, Loss: 0.0884
# [GCEALs] Epoch 20/20, Loss: 0.0735
# ✅ Final clustering performance:
# Accuracy: 0.5273
# ARI: -0.0444
# Saved results to gceals_results.json
#
# 🏁 Tuning finished.
# Best acc: 0.6510
# Best config: latent_dim=5
